# %%
import os
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin

def download_google_images(query, num_images):
    query = query.replace(" ", "+")

    if not os.path.exists(query):
        os.makedirs(query)

    url = f"https://www.google.com/search?q={query}&tbm=isch"
    response = requests.get(url)

    if response.status_code == 200:
        soup = BeautifulSoup(response.text, "html.parser")
        img_tags = soup.find_all("img")

        i = 0  # Initialize the count
        for img_tag in img_tags[:num_images]:
            img_url = img_tag.get("src")

            if img_url and img_url.startswith("http"):
                img_url = urljoin(url, img_url)

                try:
                    img_data = requests.get(img_url).content
                    with open(f"{query}/{query}{i}.jpg", "wb") as img_file:
                        img_file.write(img_data)
                    print(f"Downloaded {i}/{num_images - 1} images")
                    i += 1  # Increment the count only if download is successful
                except Exception as e:
                    print(f"Error downloading image {i}: {e}")
                    continue

        print(f"Downloaded {i} images for '{query}'")
    else:
        print("Failed to connect to Google Images")

# Example usage: Download 5 lion images
download_google_images("lion", 5)
# Out:
# Downloaded 0/3 images
# Downloaded 1/3 images
# Error downloading image 2: HTTPSConnectionPool(host='encrypted-tbn0.gstatic.com', port=443): Max retries exceeded with url: /images?q=tbn:ANd9GcTr1WF8z6uEgrnYmQBP_hDP2EyCHIQSJIaPTkQyAXlHGGNY1PYLN8RKxMWbBAE&s (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x0000027098E4E530>, 'Connection to encrypted-tbn0.gstatic.com timed out. (connect timeout=None)'))
# Downloaded 2 images for 'lion'

# %%
import os
import cv2

def convert_to_black_and_white_folder(input_folder, output_folder):
    # Create the output folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # Get a list of all subfolders in the input folder
    subfolders = [f.name for f in os.scandir(input_folder) if f.is_dir()]

    # Loop through each subfolder in the input folder
    for subfolder in subfolders:
        input_subfolder = os.path.join(input_folder, subfolder)
        output_subfolder = os.path.join(output_folder, subfolder)

        # Create a subfolder in bw_output for the current category
        if not os.path.exists(output_subfolder):
            os.makedirs(output_subfolder)

        # Get a list of all files in the current subfolder
        files = os.listdir(input_subfolder)

        # Loop through each file in the current subfolder
        for i, file in enumerate(files):
            # Construct the full path for the input image
            input_path = os.path.join(input_subfolder, file)

            # Read the image
            img = cv2.imread(input_path)

            # Check if the image is loaded successfully
            if img is None:
                print(f"Failed to load image: {input_path}")
                continue  # Skip to the next iteration

            # Convert the image to grayscale
            gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

            # Construct the full path for the output image
            output_path = os.path.join(output_subfolder, f"{i + 1}.jpg")

            # Save the black and white image
            cv2.imwrite(output_path, gray_img)

            print(f"Converted {file} in {subfolder} to black and white as {i + 1}.jpg")

# Example usage:
# Replace 'color_input' and 'bw_output' with your input and output folder paths
convert_to_black_and_white_folder('color_input', 'bw_output')
# Out:
# Converted 1.jpg in Bike to black and white as 1.jpg
# Converted 10.jpg in Bike to black and white as 2.jpg
# Converted 11.jpg in Bike to black and white as 3.jpg
# Converted 12.jpg in Bike to black and white as 4.jpg
# Converted 13.jpg in Bike to black and white as 5.jpg
# Converted 14.jpg in Bike to black and white as 6.jpg
# Converted 15.jpg in Bike to black and white as 7.jpg
# Converted 16.jpg in Bike to black and white as 8.jpg
# Converted 17.jpg in Bike to black and white as 9.jpg
# Converted 18.jpg in Bike to black and white as 10.jpg
# Converted 19.jpg in Bike to black and white as 11.jpg
# Converted 2.jpg in Bike to black and white as 12.jpg
# Converted 20.jpg in Bike to black and white as 13.jpg
# Converted 21.jpg in Bike to black and white as 14.jpg
# Converted 9.jpg in Bird to black and white as 32.jpg
# Converted 1.jpg in Car to black and white as 1.jpg
# Converted 10.jpg in Car to black and white as 2.jpg
# Converted 11.jpg in Car to black and white as 3.jpg
# Converted 12.jpg in Car to black and white as 4.jpg
# Converted 13.jpg in Car to black and white as 5.jpg
# Converted 14.jpg in Car to black and white as 6.jpg
# Converted 15.jpg in Car to black and white as 7.jpg
# Converted 16.jpg in Car to black and white as 8.jpg
# Converted 17.jpg in Car to black and white as 9.jpg
# Converted 18.jpg in Car to black and white as 10.jpg
# Converted 19.jpg in Car to black and white as 11.jpg
# Converted 2.jpg in Car to black and white as 12.jpg
# Converted 20.jpg in Car to black and white as 13.jpg
# Converted 21.jpg in Car to black and white as 14.jpg
# Converted 22.jpg in Car to black and white as 15.jpg
# Converted 23.jpg in Car to black and white as 16.jpg
# Converted 24.jpg in Car to black and white as 17.jpg
# Converted 25.jpg in Car to black and white as 18.jpg
# Converted 26.jpg in Car to black and white as 19.jpg
# Converted 27.jpg in Car to black and white as 20.jpg
# Converted 28.jpg in Car to black and white as 21.jpg
# Converted 29.jpg in Car to black and white as 22.jpg
# Converted 3.jpg in Car to black and white as 23.jpg
# Converted 30.jpg in Car to black and white as 24.jpg
# Converted 31.jpg in Car to black and white as 25.jpg
# Converted 32.jpg in Car to black and white as 26.jpg
# Converted 33.jpg in Car to black and white as 27.jpg
# Converted 34.jpg in Car to black and white as 28.jpg
# Converted 35.jpg in Car to black and white as 29.jpg
# Converted 36.jpg in Car to black and white as 30.jpg
# Converted 37.jpg in Car to black and white as 31.jpg
# Converted 38.jpg in Car to black and white as 32.jpg
# Converted 39.jpg in Car to black and white as 33.jpg
# Converted 4.jpg in Car to black and white as 34.jpg
# Converted 40.jpg in Car to black and white as 35.jpg
# Converted 41.jpg in Car to black and white as 36.jpg
# Converted 42.jpg in Car to black and white as 37.jpg
# Converted 43.jpg in Car to black and white as 38.jpg
# Converted 44.jpg in Car to black and white as 39.jpg
# Converted 45.jpg in Car to black and white as 40.jpg
# Converted 5.jpg in Car to black and white as 41.jpg
# Converted 6.jpg in Car to black and white as 42.jpg
# Converted 7.jpg in Car to black and white as 43.jpg
# Converted 8.jpg in Car to black and white as 44.jpg
# Converted 9.jpg in Car to black and white as 45.jpg
# Converted 1.jpg in Cat to black and white as 1.jpg
# Converted 10.jpg in Cat to black and white as 2.jpg
# Converted 11.jpg in Cat to black and white as 3.jpg
# Converted 12.jpg in Cat to black and white as 4.jpg
# Converted 13.jpg in Cat to black and white as 5.jpg
# Converted 14.jpg in Cat to black and white as 6.jpg
# Converted 15.jpg in Cat to black and white as 7.jpg
# Converted 16.jpg in Cat to black and white as 8.jpg
# Converted 17.jpg in Cat to black and white as 9.jpg
# Converted 18.jpg in Cat to black and white as 10.jpg
# Converted 19.jpg in Cat to black and white as 11.jpg
# Converted 2.jpg in Cat to black and white as 12.jpg
# Converted 20.jpg in Cat to black and white as 13.jpg
# Converted 21.jpg in Cat to black and white as 14.jpg
# Converted 22.jpg in Cat to black and white as 15.jpg
# Converted 23.jpg in Cat to black and white as 16.jpg
# Converted 24.jpg in Cat to black and white as 17.jpg
# Converted 25.jpg in Cat to black and white as 18.jpg
# Converted 26.jpg in Cat to black and white as 19.jpg
# Converted 27.jpg in Cat to black and white as 20.jpg
# Converted 28.jpg in Cat to black and white as 21.jpg
# Converted 29.jpg in Cat to black and white as 22.jpg
# Converted 3.jpg in Cat to black and white as 23.jpg
# Converted 30.jpg in Cat to black and white as 24.jpg
# Converted 31.jpg in Cat to black and white as 25.jpg
# Converted 32.jpg in Cat to black and white as 26.jpg
# Converted 33.jpg in Cat to black and white as 27.jpg
# Converted 34.jpg in Cat to black and white as 28.jpg
# Converted 35.jpg in Cat to black and white as 29.jpg
# Converted 36.jpg in Cat to black and white as 30.jpg
# Converted 37.jpg in Cat to black and white as 31.jpg
# Converted 38.jpg in Cat to black and white as 32.jpg
# Converted 39.jpg in Cat to black and white as 33.jpg
# Converted 4.jpg in Cat to black and white as 34.jpg
# Converted 40.jpg in Cat to black and white as 35.jpg
# Converted 41.jpg in Cat to black and white as 36.jpg
# Converted 42.jpg in Cat to black and white as 37.jpg
# Converted 43.jpg in Cat to black and white as 38.jpg
# Converted 44.jpg in Cat to black and white as 39.jpg
# Converted 45.jpg in Cat to black and white as 40.jpg
# Converted 46.jpg in Cat to black and white as 41.jpg
# Converted 47.jpg in Cat to black and white as 42.jpg
# Converted 48.jpg in Cat to black and white as 43.jpg
# Converted 49.jpg in Cat to black and white as 44.jpg
# Converted 5.jpg in Cat to black and white as 45.jpg
# Converted 6.jpg in Cat to black and white as 46.jpg
# Converted 7.jpg in Cat to black and white as 47.jpg
# Converted 8.jpg in Cat to black and white as 48.jpg
# Converted 9.jpg in Cat to black and white as 49.jpg
# Converted 1.jpg in Dog to black and white as 1.jpg
# Converted 10.jpg in Dog to black and white as 2.jpg
# Converted 11.jpg in Dog to black and white as 3.jpg
# Converted 12.jpg in Dog to black and white as 4.jpg
# Converted 13.jpg in Dog to black and white as 5.jpg
# Converted 14.jpg in Dog to black and white as 6.jpg
# Converted 15.jpg in Dog to black and white as 7.jpg
# Converted 16.jpg in Dog to black and white as 8.jpg
# Converted 17.jpg in Dog to black and white as 9.jpg
# Converted 18.jpg in Dog to black and white as 10.jpg
# Converted 19.jpg in Dog to black and white as 11.jpg
# Converted 2.jpg in Dog to black and white as 12.jpg
# Converted 20.jpg in Dog to black and white as 13.jpg
# Converted 21.jpg in Dog to black and white as 14.jpg
# Converted 22.jpg in Dog to black and white as 15.jpg
# Converted 23.jpg in Dog to black and white as 16.jpg
# Converted 24.jpg in Dog to black and white as 17.jpg
# Converted 25.jpg in Dog to black and white as 18.jpg
# Converted 26.jpg in Dog to black and white as 19.jpg
# Converted 27.jpg in Dog to black and white as 20.jpg
# Converted 28.jpg in Dog to black and white as 21.jpg
# Converted 29.jpg in Dog to black and white as 22.jpg
# Converted 3.jpg in Dog to black and white as 23.jpg
# Converted 30.jpg in Dog to black and white as 24.jpg
# Converted 31.jpg in Dog to black and white as 25.jpg
# Converted 32.jpg in Dog to black and white as 26.jpg
# Converted 33.jpg in Dog to black and white as 27.jpg
# Converted 34.jpg in Dog to black and white as 28.jpg
# Converted 35.jpg in Dog to black and white as 29.jpg
# Converted 36.jpg in Dog to black and white as 30.jpg
# Converted 37.jpg in Dog to black and white as 31.jpg
# Converted 38.jpg in Dog to black and white as 32.jpg
# Converted 39.jpg in Dog to black and white as 33.jpg
# Converted 4.jpg in Dog to black and white as 34.jpg
# Converted 40.jpg in Dog to black and white as 35.jpg
# Converted 41.jpg in Dog to black and white as 36.jpg
# Converted 42.jpg in Dog to black and white as 37.jpg
# Converted 43.jpg in Dog to black and white as 38.jpg
# Converted 44.jpg in Dog to black and white as 39.jpg
# Converted 45.jpg in Dog to black and white as 40.jpg
# Converted 46.jpg in Dog to black and white as 41.jpg
# Converted 47.jpg in Dog to black and white as 42.jpg
# Converted 48.jpg in Dog to black and white as 43.jpg
# Converted 49.jpg in Dog to black and white as 44.jpg
# Converted 5.jpg in Dog to black and white as 45.jpg
# Converted 6.jpg in Dog to black and white as 46.jpg
# Converted 7.jpg in Dog to black and white as 47.jpg
# Converted 8.jpg in Dog to black and white as 48.jpg
# Converted 9.jpg in Dog to black and white as 49.jpg
# Converted 1.jpg in Food to black and white as 1.jpg
# Converted 10.jpg in Food to black and white as 2.jpg
# Converted 11.jpg in Food to black and white as 3.jpg
# Converted 12.jpg in Food to black and white as 4.jpg
# Converted 13.jpg in Food to black and white as 5.jpg
# Converted 14.jpg in Food to black and white as 6.jpg
# Converted 15.jpg in Food to black and white as 7.jpg
# Converted 16.jpg in Food to black and white as 8.jpg
# Converted 17.jpg in Food to black and white as 9.jpg
# Converted 18.jpg in Food to black and white as 10.jpg
# Converted 19.jpg in Food to black and white as 11.jpg
# Converted 2.jpg in Food to black and white as 12.jpg
# Converted 20.jpg in Food to black and white as 13.jpg
# Converted 21.jpg in Food to black and white as 14.jpg
# Converted 22.jpg in Food to black and white as 15.jpg
# Converted 23.jpg in Food to black and white as 16.jpg
# Converted 24.jpg in Food to black and white as 17.jpg
# Converted 25.jpg in Food to black and white as 18.jpg
# Converted 26.jpg in Food to black and white as 19.jpg
# Converted 27.jpg in Food to black and white as 20.jpg
# Converted 28.jpg in Food to black and white as 21.jpg
# Converted 29.jpg in Food to black and white as 22.jpg
# Converted 3.jpg in Food to black and white as 23.jpg
# Converted 30.jpg in Food to black and white as 24.jpg
# Converted 31.jpg in Food to black and white as 25.jpg
# Converted 32.jpg in Food to black and white as 26.jpg
# Converted 33.jpg in Food to black and white as 27.jpg
# Converted 34.jpg in Food to black and white as 28.jpg
# Converted 35.jpg in Food to black and white as 29.jpg
# Converted 36.jpg in Food to black and white as 30.jpg
# Converted 37.jpg in Food to black and white as 31.jpg
# Converted 38.jpg in Food to black and white as 32.jpg
# Converted 39.jpg in Food to black and white as 33.jpg
# Converted 4.jpg in Food to black and white as 34.jpg
# Converted 40.jpg in Food to black and white as 35.jpg
# Converted 41.jpg in Food to black and white as 36.jpg
# Converted 5.jpg in Food to black and white as 37.jpg
# Converted 6.jpg in Food to black and white as 38.jpg
# Converted 7.jpg in Food to black and white as 39.jpg
# Converted 8.jpg in Food to black and white as 40.jpg
# Converted 9.jpg in Food to black and white as 41.jpg
# Converted 1.jpg in Lion to black and white as 1.jpg
# Converted 10.jpg in Lion to black and white as 2.jpg
# Converted 11.jpg in Lion to black and white as 3.jpg
# Converted 12.jpg in Lion to black and white as 4.jpg
# Converted 15.jpg in Tiger to black and white as 7.jpg
# Converted 16.jpg in Tiger to black and white as 8.jpg
# Converted 17.jpg in Tiger to black and white as 9.jpg
# Converted 18.jpg in Tiger to black and white as 10.jpg
# Converted 19.jpg in Tiger to black and white as 11.jpg
# Converted 2.jpg in Tiger to black and white as 12.jpg
# Converted 20.jpg in Tiger to black and white as 13.jpg
# Converted 21.jpg in Tiger to black and white as 14.jpg
# Converted 22.jpg in Tiger to black and white as 15.jpg
# Converted 23.jpg in Tiger to black and white as 16.jpg
# Converted 24.jpg in Tiger to black and white as 17.jpg
# Converted 25.jpg in Tiger to black and white as 18.jpg
# Converted 26.jpg in Tiger to black and white as 19.jpg
# Converted 27.jpg in Tiger to black and white as 20.jpg
# Converted 28.jpg in Tiger to black and white as 21.jpg
# Converted 29.jpg in Tiger to black and white as 22.jpg
# Converted 3.jpg in Tiger to black and white as 23.jpg
# Converted 30.jpg in Tiger to black and white as 24.jpg
# Converted 31.jpg in Tiger to black and white as 25.jpg
# Converted 32.jpg in Tiger to black and white as 26.jpg
# Converted 33.jpg in Tiger to black and white as 27.jpg
# Converted 34.jpg in Tiger to black and white as 28.jpg
# Converted 35.jpg in Tiger to black and white as 29.jpg
# Converted 36.jpg in Tiger to black and white as 30.jpg
# Converted 37.jpg in Tiger to black and white as 31.jpg
# Converted 38.jpg in Tiger to black and white as 32.jpg
# Converted 39.jpg in Tiger to black and white as 33.jpg
# Converted 4.jpg in Tiger to black and white as 34.jpg
# Converted 40.jpg in Tiger to black and white as 35.jpg
# Converted 41.jpg in Tiger to black and white as 36.jpg
# Converted 42.jpg in Tiger to black and white as 37.jpg
# Converted 43.jpg in Tiger to black and white as 38.jpg
# Converted 44.jpg in Tiger to black and white as 39.jpg
# Converted 45.jpg in Tiger to black and white as 40.jpg
# Converted 46.jpg in Tiger to black and white as 41.jpg
# Converted 47.jpg in Tiger to black and white as 42.jpg
# Converted 48.jpg in Tiger to black and white as 43.jpg
# Converted 49.jpg in Tiger to black and white as 44.jpg
# Converted 5.jpg in Tiger to black and white as 45.jpg
# Converted 6.jpg in Tiger to black and white as 46.jpg
# Converted 7.jpg in Tiger to black and white as 47.jpg
# Converted 8.jpg in Tiger to black and white as 48.jpg
# Converted 9.jpg in Tiger to black and white as 49.jpg

# %%
import os
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin

def download_google_images(query, num_images):
    # Create a directory to save the images
    if not os.path.exists(query):
        os.makedirs(query)

    # Perform a Google Image search
    url = f"https://unsplash.com/s/photos/Bird"
    response = requests.get(url)

    if response.status_code == 200:
        soup = BeautifulSoup(response.text, "html.parser")
        img_tags = soup.select("img[src^='https://images.unsplash.com/photo']")

        # Download the first 'num_images' images
        for i, img_tag in enumerate(img_tags[:num_images]):
            img_url = img_tag.get("src")

            # Check if the URL starts with "http" to filter out non-image URLs
            if img_url and img_url.startswith("http"):
                img_url = urljoin(url, img_url)  # Ensure absolute URL
                img_data = requests.get(img_url).content

                # Save the images with sequential names
                img_path = os.path.join(query, f"{i + 1}.jpg")

                with open(img_path, "wb") as img_file:
                    img_file.write(img_data)

                print(f"Downloaded {i + 1}/{num_images} images")

        print(f"Downloaded {num_images} images in numeric order")
    else:
        print("Failed to connect to Google Images")

# Example usage: Download 5 images in numeric order
download_google_images("Bird", 100)
# Out:
# Downloaded 1/100 images
# Downloaded 2/100 images
# Downloaded 3/100 images
# Downloaded 4/100 images
# Downloaded 5/100 images
# Downloaded 6/100 images
# Downloaded 7/100 images
# Downloaded 8/100 images
# Downloaded 9/100 images
# Downloaded 10/100 images
# Downloaded 11/100 images
# Downloaded 12/100 images
# Downloaded 13/100 images
# Downloaded 14/100 images
# Downloaded 15/100 images
# Downloaded 16/100 images
# Downloaded 17/100 images
# Downloaded 18/100 images
# Downloaded 19/100 images
# Downloaded 20/100 images
# Downloaded 21/100 images
# Downloaded 22/100 images
# Downloaded 23/100 images
# Downloaded 24/100 images
# Downloaded 25/100 images
# Downloaded 26/100 images
# Downloaded 27/100 images
# Downloaded 28/100 images
# Downloaded 29/100 images
# Downloaded 30/100 images
# Downloaded 31/100 images
# Downloaded 32/100 images

# %%
import os

def rename_images(folder_path):
    # Get a list of all files in the folder
    files = os.listdir(folder_path)

    # Sort the files based on their numeric part
    sorted_files = sorted(files, key=lambda x: int(x.split('.')[0]))

    # Rename the files sequentially
    for i, old_name in enumerate(sorted_files):
        extension = os.path.splitext(old_name)[1]
        new_name = f"{i + 1}{extension}"

        old_path = os.path.join(folder_path, old_name)
        new_path = os.path.join(folder_path, new_name)

        os.rename(old_path, new_path)
        print(f"Renamed: {old_name} -> {new_name}")

# Replace 'path_to_your_folder' with the actual path to your folder
folder_path = 'color_input\Food'
rename_images(folder_path)
# Out:
# Renamed: 1.jpg -> 1.jpg
# Renamed: 2.jpg -> 2.jpg
# Renamed: 3.jpg -> 3.jpg
# Renamed: 4.jpg -> 4.jpg
# Renamed: 5.jpg -> 5.jpg
# Renamed: 7.jpg -> 6.jpg
# Renamed: 8.jpg -> 7.jpg
# Renamed: 9.jpg -> 8.jpg
# Renamed: 10.jpg -> 9.jpg
# Renamed: 12.jpg -> 10.jpg
# Renamed: 13.jpg -> 11.jpg
# Renamed: 14.jpg -> 12.jpg
# Renamed: 15.jpg -> 13.jpg
# Renamed: 17.jpg -> 14.jpg
# Renamed: 18.jpg -> 15.jpg
# Renamed: 19.jpg -> 16.jpg
# Renamed: 21.jpg -> 17.jpg
# Renamed: 22.jpg -> 18.jpg
# Renamed: 23.jpg -> 19.jpg
# Renamed: 24.jpg -> 20.jpg
# Renamed: 25.jpg -> 21.jpg
# Renamed: 26.jpg -> 22.jpg
# Renamed: 27.jpg -> 23.jpg
# Renamed: 28.jpg -> 24.jpg
# Renamed: 29.jpg -> 25.jpg
# Renamed: 30.jpg -> 26.jpg
# Renamed: 31.jpg -> 27.jpg
# Renamed: 32.jpg -> 28.jpg
# Renamed: 33.jpg -> 29.jpg
# Renamed: 34.jpg -> 30.jpg
# Renamed: 35.jpg -> 31.jpg
# Renamed: 36.jpg -> 32.jpg
# Renamed: 37.jpg -> 33.jpg
# Renamed: 38.jpg -> 34.jpg
# Renamed: 39.jpg -> 35.jpg
# Renamed: 40.jpg -> 36.jpg
# Renamed: 41.jpg -> 37.jpg
# Renamed: 42.jpg -> 38.jpg
# Renamed: 43.jpg -> 39.jpg
# Renamed: 44.jpg -> 40.jpg
# Renamed: 45.jpg -> 41.jpg
